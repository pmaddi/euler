# %%
from problem_91 import *
import matplotlib.pyplot as plt
plt.plot([2, 5], [16,2], 'ro')  
plt.axis([0, 6, 0, 20]) 
plt.show()

# %%
cnt = 0                                                                                                                                                                                                                                  
n = 5
st = set()
for p in points(n):
    for q in points(n):                                                                                                                                                                                                                  
        if p != q and forms_right_triangle(p, q):
            st.add((min(p, q), max(p, q))) 
            plt.figure(figsize=(5, 5))

            plt.plot([0, p[0], q[0]], [0, p[1], q[1]], 'ro')  
            plt.axis([0, 5, 0, 5]) 

            plt.show()
            # print(p, q)                                                                                                                                                                                                                  
            cnt += 1                                                                                                                                                                                                                     
plt.show()

# %%
((2,4), (3,3)) in st
# Out:
# True
